# %%
import pandas as pd

# %%
data = {
    "Customer_ID": [101,102,103,104,105,106,107,108,109,110,111,112],
    "Annual_Revenue": [12000, 18500, 13200, 15400, 22300, 28900,
                       17500, 19800, 24100, 16700, 21000, 30500]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#     Customer_ID  Annual_Revenue
# 0           101           12000
# 1           102           18500
# 2           103           13200
# 3           104           15400
# 4           105           22300
# 5           106           28900
# 6           107           17500
# 7           108           19800
# 8           109           24100
# 9           110           16700
# 10          111           21000
# 11          112           30500

# %%
df['Annual_Revenue'].max()-df['Annual_Revenue'].min()
# Out:
# 18500

# %%
revenue_range = df["Annual_Revenue"].max() - df["Annual_Revenue"].min()
revenue_range
# Out:
# 18500

# %%
variance = df["Annual_Revenue"].var()

# %%
variance
# Out:
# 33035378.787878785

# %%
std_dev = df["Annual_Revenue"].std()
std_dev
# Out:
# 5747.641149887385

# %%
coeff_var = (std_dev / df["Annual_Revenue"].mean()) * 100

# %%
coeff_var
# Out:
# np.float64(28.75018499318408)
