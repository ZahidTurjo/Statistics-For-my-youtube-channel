# %%
import numpy as np
import pandas as pd

data = [12, 15, 14, 10, 18, 20, 22, 25, 30, 35, 40]
df = pd.DataFrame({"values": data})

df
# Out:
#     values
# 0       12
# 1       15
# 2       14
# 3       10
# 4       18
# 5       20
# 6       22
# 7       25
# 8       30
# 9       35
# 10      40

# %%
Q1 = df['values'].quantile(0.25)
Q2 = df['values'].quantile(0.50)   # Median
Q3 = df['values'].quantile(0.75)

print("Q1:", Q1)
print("Q2 (Median):", Q2)
print("Q3:", Q3)
# Out:
# Q1: 14.5
# Q2 (Median): 20.0
# Q3: 27.5

# %%
IQR = Q3 - Q1 #Measure Middle 50% data speard
print("IQR:", IQR)
# Out:
# IQR: 13.0

# %% [markdown]
# **Outlier Detect**

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: -5.0
# Upper Bound: 47.0

# %%
outliers = df[(df['values'] < lower_bound) | (df['values'] > upper_bound)]
outliers
# Out:
# Empty DataFrame
# Columns: [values]
# Index: []

# %% [markdown]
# **BOX PLOT**

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.boxplot(df['values'])
y = np.random.normal(1, 0.04, size=len(data))
plt.plot(y, df['values'], 'o')
plt.title("Boxplot")
plt.ylabel("Values")
plt.show()

# %%
marks = [35, 40, 42, 45, 50, 55, 60, 65, 95]

plt.boxplot(marks)
y = np.random.normal(1, 0.04, size=len(marks))
plt.plot(y, marks, 'o')
plt.title("Student Marks Boxplot")
plt.show()
